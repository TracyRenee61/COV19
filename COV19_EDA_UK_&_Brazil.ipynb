# %% [markdown]
# Import libraries

# %% [markdown]
# Taken from website:-
# https://ourworldindata.org/coronavirus-source-data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read files

# %%
# load datasets
df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')
df
# Out:
#       iso_code continent  ... human_development_index excess_mortality
# 0          AFG      Asia  ...                   0.511              NaN
# 1          AFG      Asia  ...                   0.511              NaN
# 2          AFG      Asia  ...                   0.511              NaN
# 3          AFG      Asia  ...                   0.511              NaN
# 4          AFG      Asia  ...                   0.511              NaN
# ...        ...       ...  ...                     ...              ...
# 97121      ZWE    Africa  ...                   0.571              NaN
# 97122      ZWE    Africa  ...                   0.571              NaN
# 97123      ZWE    Africa  ...                   0.571              NaN
# 97124      ZWE    Africa  ...                   0.571              NaN
# 97125      ZWE    Africa  ...                   0.571              NaN
#
# [97126 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97126 entries, 0 to 97125
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               97126 non-null  object
#  1   continent                              92556 non-null  object
#  2   location                               97126 non-null  object
#  3   date                                   97126 non-null  object
#  4   total_cases                            93791 non-null  float64
#  5   new_cases                              93788 non-null  float64
#  6   new_cases_smoothed                     92773 non-null  float64
#  7   total_deaths                           83715 non-null  float64
#  8   new_deaths                             83871 non-null  float64
#  9   new_deaths_smoothed                    92773 non-null  float64
#  10  total_cases_per_million                93291 non-null  float64
#  11  new_cases_per_million                  93288 non-null  float64
#  12  new_cases_smoothed_per_million         92278 non-null  float64
#  13  total_deaths_per_million               83228 non-null  float64
#  14  new_deaths_per_million                 83384 non-null  float64
#  15  new_deaths_smoothed_per_million        92278 non-null  float64
#  16  reproduction_rate                      77967 non-null  float64
#  17  icu_patients                           9792 non-null   float64
#  18  icu_patients_per_million               9792 non-null   float64
#  19  hosp_patients                          12175 non-null  float64
#  20  hosp_patients_per_million              12175 non-null  float64
#  21  weekly_icu_admissions                  896 non-null    float64
#  22  weekly_icu_admissions_per_million      896 non-null    float64
#  23  weekly_hosp_admissions                 1528 non-null   float64
#  24  weekly_hosp_admissions_per_million     1528 non-null   float64
#  25  new_tests                              43586 non-null  float64
#  26  total_tests                            43279 non-null  float64
#  27  total_tests_per_thousand               43279 non-null  float64
#  28  new_tests_per_thousand                 43586 non-null  float64
#  29  new_tests_smoothed                     50621 non-null  float64
#  30  new_tests_smoothed_per_thousand        50621 non-null  float64
#  31  positive_rate                          47243 non-null  float64
#  32  tests_per_case                         46645 non-null  float64
#  33  tests_units                            52252 non-null  object
#  34  total_vaccinations                     15256 non-null  float64
#  35  people_vaccinated                      14496 non-null  float64
#  36  people_fully_vaccinated                11639 non-null  float64
#  37  new_vaccinations                       12729 non-null  float64
#  38  new_vaccinations_smoothed              26332 non-null  float64
#  39  total_vaccinations_per_hundred         15256 non-null  float64
#  40  people_vaccinated_per_hundred          14496 non-null  float64
#  41  people_fully_vaccinated_per_hundred    11639 non-null  float64
#  42  new_vaccinations_smoothed_per_million  26332 non-null  float64
#  43  stringency_index                       81649 non-null  float64
#  44  population                             96492 non-null  float64
#  45  population_density                     90274 non-null  float64
#  46  median_age                             86891 non-null  float64
#  47  aged_65_older                          85913 non-null  float64
#  48  aged_70_older                          86410 non-null  float64
#  49  gdp_per_capita                         87228 non-null  float64
#  50  extreme_poverty                        58914 non-null  float64
#  51  cardiovasc_death_rate                  87274 non-null  float64
#  52  diabetes_prevalence                    89468 non-null  float64
#  53  female_smokers                         68301 non-null  float64
#  54  male_smokers                           67302 non-null  float64
#  55  handwashing_facilities                 43853 non-null  float64
#  56  hospital_beds_per_thousand             79545 non-null  float64
#  57  life_expectancy                        92235 non-null  float64
#  58  human_development_index                87454 non-null  float64
#  59  excess_mortality                       3407 non-null   float64
# dtypes: float64(55), object(5)
# memory usage: 44.5+ MB

# %% [markdown]
# Convert date to number

# %%
import datetime 

date = df.date

df['date'] = pd.to_datetime(df['date'], errors='coerce')
df['date_num'] = df['date'].dt.strftime('%d%m%Y')
df
# Out:
#       iso_code continent  ... excess_mortality  date_num
# 0          AFG      Asia  ...              NaN  24022020
# 1          AFG      Asia  ...              NaN  25022020
# 2          AFG      Asia  ...              NaN  26022020
# 3          AFG      Asia  ...              NaN  27022020
# 4          AFG      Asia  ...              NaN  28022020
# ...        ...       ...  ...              ...       ...
# 97121      ZWE    Africa  ...              NaN  16062021
# 97122      ZWE    Africa  ...              NaN  17062021
# 97123      ZWE    Africa  ...              NaN  18062021
# 97124      ZWE    Africa  ...              NaN  19062021
# 97125      ZWE    Africa  ...              NaN  20062021
#
# [97126 rows x 61 columns]

# %% [markdown]
# Percent new deaths to new cases

# %%
df['per_death_to_case'] = df.new_cases / df.new_deaths
df
# Out:
#       iso_code continent  ...  date_num per_death_to_case
# 0          AFG      Asia  ...  24022020               NaN
# 1          AFG      Asia  ...  25022020               NaN
# 2          AFG      Asia  ...  26022020               NaN
# 3          AFG      Asia  ...  27022020               NaN
# 4          AFG      Asia  ...  28022020               NaN
# ...        ...       ...  ...       ...               ...
# 97121      ZWE    Africa  ...  16062021         79.333333
# 97122      ZWE    Africa  ...  17062021         53.000000
# 97123      ZWE    Africa  ...  18062021         45.333333
# 97124      ZWE    Africa  ...  19062021         29.300000
# 97125      ZWE    Africa  ...  20062021         25.166667
#
# [97126 rows x 62 columns]

# %% [markdown]
# Country

# %%
country = df['location'].to_list()

# using naive method to remove duplicated from list  
list_country = [] 
for i in country: 
    if i not in list_country: 
        list_country.append(i) 

list_country
# Out:
# ['Afghanistan',
#  'Africa',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Asia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bonaire Sint Eustatius and Saba',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Cook Islands',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czechia',
#  'Democratic Republic of Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Europe',
#  'European Union',
#  'Faeroe Islands',
#  'Falkland Islands',
#  'Fiji',
#  'Finland',
#  'France',
#  'French Polynesia',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guatemala',
#  'Guernsey',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'International',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jersey',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Macao',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Marshall Islands',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Micronesia (country)',
#  'Moldova',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Montserrat',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands',
#  'New Caledonia',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North America',
#  'North Macedonia',
#  'Northern Cyprus',
#  'Norway',
#  'Oceania',
#  'Oman',
#  'Pakistan',
#  'Palau',
#  'Palestine',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Pitcairn',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saint Helena',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Vincent and the Grenadines',
#  'Samoa',
#  'San Marino',
#  'Sao Tome and Principe',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Sint Maarten (Dutch part)',
#  'Slovakia',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South America',
#  'South Korea',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Timor',
#  'Togo',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Vatican',
#  'Venezuela',
#  'Vietnam',
#  'Wallis and Futuna',
#  'World',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
print(len(list_country))
# Out:
# 231

# %% [markdown]
# Graphical Representation

# %%
import seaborn as sns
import matplotlib.pyplot as plt

var = 'continent'
data = pd.concat([df['new_cases'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="new_cases", data=data)
fig.axis(ymin=0, ymax=500000);

# %%
var = 'continent'
data = pd.concat([df['new_deaths'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="new_deaths", data=data)
fig.axis(ymin=0, ymax=20000);

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)

# %% [markdown]
# Countries

# %%
country = "United Kingdom"

include_uk = df[df['location'].values == country]
exclude_uk = df[df['location'].values != country]
uk_cov19 = include_uk
uk_cov19
# Out:
#       iso_code continent  ...  date_num per_death_to_case
# 91545      GBR    Europe  ...  31012020               NaN
# 91546      GBR    Europe  ...  01022020               NaN
# 91547      GBR    Europe  ...  02022020               NaN
# 91548      GBR    Europe  ...  03022020               NaN
# 91549      GBR    Europe  ...  04022020               NaN
# ...        ...       ...  ...       ...               ...
# 92047      GBR    Europe  ...  16062021        979.000000
# 92048      GBR    Europe  ...  17062021        569.631579
# 92049      GBR    Europe  ...  18062021        935.181818
# 92050      GBR    Europe  ...  19062021        719.714286
# 92051      GBR    Europe  ...  20062021       1512.833333
#
# [507 rows x 62 columns]

# %%
country = "Brazil"

include_b = df[df['location'].values == country]
exclude_b = df[df['location'].values != country]
b_cov19 = include_b
b_cov19
# Out:
#       iso_code      continent  ...  date_num per_death_to_case
# 12357      BRA  South America  ...  26022020               NaN
# 12358      BRA  South America  ...  27022020               NaN
# 12359      BRA  South America  ...  28022020               NaN
# 12360      BRA  South America  ...  29022020               NaN
# 12361      BRA  South America  ...  01032020               NaN
# ...        ...            ...  ...       ...               ...
# 12833      BRA  South America  ...  16062021         31.820821
# 12834      BRA  South America  ...  17062021         32.038944
# 12835      BRA  South America  ...  18062021         39.612024
# 12836      BRA  South America  ...  19062021         35.761843
# 12837      BRA  South America  ...  20062021         43.100488
#
# [481 rows x 62 columns]

# %% [markdown]
# UK

# %%
plt.plot(uk_cov19.date, uk_cov19.new_cases_per_million)
plt.xlabel('Date')
plt.ylabel('New Cases per Million UK')
plt.title('New Cases per Million UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.new_deaths_per_million)
plt.xlabel('Date')
plt.ylabel('New Deaths per Million UK')
plt.title('New Deaths per Million UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.per_death_to_case)
plt.xlabel('Date')
plt.ylabel('Percent Death to New Cases UK')
plt.title('Percent Death to New Cases UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.female_smokers)
plt.plot(uk_cov19.date, uk_cov19.male_smokers)
plt.legend(['Female Smokers', 'Male Smokers'])
plt.xlabel('Date')
plt.ylabel('Ratio of Female to Male Smokers')
plt.title('Ratio of Female to Male Smokers')
plt.show()

# %% [markdown]
# Brazil

# %%
plt.plot(b_cov19.date, b_cov19.new_cases_per_million)
plt.xlabel('Date')
plt.ylabel('New Cases per Million Brazil')
plt.title('New Cases per Million Brazil')
plt.show()

# %%
plt.plot(b_cov19.date, b_cov19.new_deaths_per_million)
plt.xlabel('Date')
plt.ylabel('New Deaths per Million Brazil')
plt.title('New Deaths per Million Brazil')
plt.show()

# %%
plt.plot(b_cov19.date, b_cov19.per_death_to_case)
plt.xlabel('Date')
plt.ylabel('Percent Death to New Cases Brazil')
plt.title('Percent Death to New Cases Brazil')
plt.show()

# %%
plt.plot(b_cov19.date, b_cov19.female_smokers)
plt.plot(b_cov19.date, b_cov19.male_smokers)
plt.legend(['Female Smokers', 'Male Smokers'])
plt.xlabel('Date')
plt.ylabel('Ratio of Female to Male Smokers Brazil')
plt.title('Ratio of Female to Male Smokers Brazil')
plt.show()

# %% [markdown]
# Comparisons

# %%
plt.plot(uk_cov19.date, uk_cov19.new_cases_per_million)
plt.plot(b_cov19.date, b_cov19.new_cases_per_million)
plt.legend(['UK', 'Brazil'])
plt.xlabel('Date')
plt.ylabel('New Cases per Million Brazil and UK')
plt.title('New Cases per Million Brazil and UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.new_deaths_per_million)
plt.plot(b_cov19.date, b_cov19.new_deaths_per_million)
plt.legend(['UK', 'Brazil'])
plt.xlabel('Date')
plt.ylabel('New Deaths per Million Brazil and UK')
plt.title('New Deaths per Million Brazil and UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.per_death_to_case)
plt.plot(b_cov19.date, b_cov19.per_death_to_case)
plt.legend(['UK', 'Brazil'])
plt.xlabel('Date')
plt.ylabel('Percent Death to New Cases Brazil and UK')
plt.title('Percent Death to New Cases Brazil and UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.median_age)
plt.plot(b_cov19.date, b_cov19.median_age)
plt.legend(['UK', 'Brazil'])
plt.xlabel('Date')
plt.ylabel('Median Age Brazil and UK')
plt.title('Median Age Brazil and UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.gdp_per_capita)
plt.plot(b_cov19.date, b_cov19.gdp_per_capita)
plt.legend(['UK', 'Brazil'])
plt.xlabel('Date')
plt.ylabel('GDP per Capita Brazil and UK')
plt.title('GDP per Capita Brazil and UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.extreme_poverty)
plt.plot(b_cov19.date, b_cov19.extreme_poverty)
plt.legend(['UK', 'Brazil'])
plt.xlabel('Date')
plt.ylabel('Extreme Poverty Brazil and UK')
plt.title('Extreme Poverty Brazil and UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.cardiovasc_death_rate)
plt.plot(b_cov19.date, b_cov19.cardiovasc_death_rate)
plt.legend(['UK', 'Brazil'])
plt.xlabel('Date')
plt.ylabel('Cardiovascular Death Rate UK and Brazil')
plt.title('Cardiovascular Death Rate UK and Brazil')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.diabetes_prevalence)
plt.plot(b_cov19.date, b_cov19.diabetes_prevalence)
plt.legend(['UK', 'Brazil'])
plt.xlabel('Date')
plt.ylabel('Diabetes Prevalence Brazil and UK')
plt.title('Diabetes Prevalence Brazil and UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.female_smokers)
plt.plot(b_cov19.date, b_cov19.female_smokers)
plt.legend(['UK', 'Brazil'])
plt.xlabel('Date')
plt.ylabel('Female Smokers Brazil and UK')
plt.title('Female Smokers Brazil and UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.male_smokers)
plt.plot(b_cov19.date, b_cov19.male_smokers)
plt.legend(['UK', 'Brazil'])
plt.xlabel('Date')
plt.ylabel('Male Smokers Brazil and UK')
plt.title('Male Smokers Brazil and UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.hospital_beds_per_thousand)
plt.plot(b_cov19.date, b_cov19.hospital_beds_per_thousand)
plt.legend(['UK', 'Brazil'])
plt.xlabel('Date')
plt.ylabel('Hospital Beds per Thousand Brazil and UK')
plt.title('Hospital Beds per Thousand Brazil and UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.life_expectancy)
plt.plot(b_cov19.date, b_cov19.life_expectancy)
plt.legend(['UK', 'Brazil'])
plt.xlabel('Date')
plt.ylabel('Life Expectancy Brazil and UK')
plt.title('Life Expectancy Brazil and UK')
plt.show()

# %%
plt.plot(uk_cov19.date, uk_cov19.human_development_index)
plt.plot(b_cov19.date, b_cov19.human_development_index)
plt.legend(['UK', 'Brazil'])
plt.xlabel('Date')
plt.ylabel('Human Development Index Brazil and UK')
plt.title('Human Development Index Brazil and UK')
plt.show()
